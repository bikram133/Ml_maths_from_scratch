# %%
#l1 norm
import pandas as pd
import numpy as np

# %%
def l2_norm(a):
 l2_norm=((a[0])**2+(a[1]**2))**0.5
 return l2_norm
print(l2_norm(a=[3,4]))
# Out:
# 5.0

# %%
def l1_norm(a):
  l1_norm=np.abs(a[0])+np.abs(a[1])
  return l1_norm
print(l1_norm(a=[3,4]))
# Out:
# 7
